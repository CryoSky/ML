# %% [markdown]
# ### Homework 1: Part 2: Implementing regularized linear regression
# In this part, you will implement regularized linear regression and use it to
# study models with different bias-variance properties.
#
# This notebook contains code that helps you get started on
# linear regression with regularization.
# You will need to complete functions in
# reg_linear_regressor.py and utils.py.
# Modify this notebook in places marked by TODO:.

# %% [markdown]
# ### Regularized linear regression: an example
# In this problem, you will implement regularized linear regression
# to predict the amount of water flowing out of a dam using the change
# of water level in a reservoir. We will begin by visualizing the dataset containing historical records on the
# change in the water level $x$, and the amount of water $y$, flowing out of the dam.
# This dataset is divided into three parts:
# - A training set that you will use to learn the model:  X,  y.
# - A validation set for determining the regularization parameter: Xval, yval.
# - A test set for evaluating the performance of your model:  Xtest, ytest. These are unseen examples that were not used during the training of the model.
#
# Run the cell below and it  will plot the training data as shown in Figure 6 in your assignment handout.

# %%
import numpy as np
import matplotlib.pyplot as plt
import utils
import plot_utils
from reg_linear_regressor_multi import RegularizedLinearReg_SquaredLoss

########################################################################
## =========== Part 1: Loading and Visualizing Data ===================#
########################################################################
# Load Training Data

print 'Loading and Visualizing Data ...'

X, y, Xtest, ytest, Xval, yval = utils.load_mat('ex2data1.mat')

# Plot training data

plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.show()
#plt.savefig('fig6.pdf')
# Out:
# Loading and Visualizing Data ...

# %% [markdown]
# ### Regularized Linear Regression cost function and gradient
# You should now implement the loss function and gradient of the
# loss function for regularized linear regression in reg_linear_regression_multi.py. Then run the cell below.
# Regularized linear regression has the following cost function:
# $$J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right) + \frac{\lambda}{2m}\left( \sum_{j=1}^{n} {\theta_j}^2 \right) $$
# where $\lambda$ is a regularization parameter which controls the degree of regularization
# (thus, help preventing overfitting). The regularization term puts
# a penalty on the overall cost $J(\theta)$. As the magnitudes of the model parameters $\theta_j$ increase, the penalty increases as well. Note that you should not regularize the $\theta_0$ term. You should now complete the code for the method loss in the class Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py to calculate $J(\theta)$. Vectorize your code and avoid writing for loops.
#
# Correspondingly, the partial derivative of the regularized linear regression  cost function
# with respect to  $\theta_j$ is defined as:
# \begin{eqnarray*}
# \frac{\partial J(\theta)}{\partial \theta_0} & = & \frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)}){x_j}^{(i)} \\
# \frac{\partial J(\theta)}{\partial \theta_j} & = & \left(\frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)} ){x_j}^{(i)}\right) + \frac{\lambda}{m}{\theta_j} \; \; \; \mbox{ for }j \geq 1\\
# \end{eqnarray*}
# You should now complete the code for the method grad_loss in the class {Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py}
# to  calculate the gradient, returning
# it in the variable grad.
#
# Then evaluate the cell below. It runs the train method in  reg_linear_regressor_multi.py to compute the optimal value
# of $\theta$. This training function uses scipy's fmin_bfgs to optimize the cost function.
# Here we have set the regularization parameter $\lambda$ to zero.
#
# The best fit line plotted by the script  tells us that the model is
# not a good fit to the data because the data is non-linear. While
# visualizing the best fit as shown is one possible way to debug your learning
# algorithm, it is not always easy to visualize the data and model. In the next
# cell, you will implement a function to generate learning curves that can
# help you debug your learning algorithm even if it is not easy to visualize the
# data.

# %%
# append a column of ones to matrix X

XX = np.vstack([np.ones((X.shape[0],)),X]).T

#  Train linear regression with lambda = 0

reglinear_reg1 = RegularizedLinearReg_SquaredLoss()
theta_opt0 = reglinear_reg1.train(XX,y,reg=0.0,num_iters=1000)
print 'Theta at lambda = 0 is ', theta_opt0

# plot fit over data and show it (or save it in fig7.pdf)
plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.plot(X,np.dot(XX,theta_opt0),'g-',linewidth=3)
plt.show()
#plt.savefig('fig7.pdf')
# Out:
# Optimization terminated successfully.
#          Current function value: 22.373906
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Theta at lambda = 0 is  [ 13.08790353   0.36777923]

# %% [markdown]
# ### Learning curve for linear regression
# An important concept in machine learning is the bias-variance tradeoff. Models
# with high bias are not complex enough for the data and tend to underfit,
# while models with high variance overfit  the training data.
# Here you will plot training and test errors on a
# learning curve to diagnose bias-variance problems.
#
# A  learning curve plots
# training and cross validation error as a function of training set size. You will complete the
# function  learning_curve in utils.py so that it returns a vector of errors for the
# training set and  validation set.
# To obtain different training set sizes,
# use different subsets of the original training set X. Specifically, for
# a training set size of $i$, you should use the first $i$ examples.
#
# You can use the train function to find the parameter {\tt theta}. Note
# that the regularization $\lambda$  is passed as a parameter to the learning_curve function.
# After learning the $\theta$ parameter, you should compute the error on the training
# and validation sets. Recall that the training error for a dataset is
# defined as:
# $$ J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right)  $$
#
#
# In particular, note that the training error does not include the regularization
# term. One way to compute the training error is to use your existing
# cost function and set the regularization parameter reg to 0 only when using it to compute the training error
# and validation error. When you are computing the training set error,
# make sure you compute it on the training subset
# instead of the entire training set. However, for the validation error,
# you should compute it over the entire validation set. You should store
# the computed errors in the vectors error_train and error_val.
# When you are finished, the cell below will print the learning curves and produce
# a plot similar to Figure 8 in the assignment handout.

# %%
reg = 1.0
XXval = np.vstack([np.ones((Xval.shape[0],)),Xval]).T

# implement the learning_curve function in utils.py
# this script will run your function and show the learning curve

error_train, error_val = utils.learning_curve(XX,y,XXval,yval,reg)
plot_utils.plot_learning_curve(error_train, error_val,reg)
plt.show()
# plt.savefig('fig8.pdf')
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.228949
#          Iterations: 1
#          Function evaluations: 114
#          Gradient evaluations: 102
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.444729
#          Iterations: 2
#          Function evaluations: 115
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: 7.301219
#          Iterations: 3
#          Function evaluations: 5
#          Gradient evaluations: 5
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.304081
#          Iterations: 4
#          Function evaluations: 89
#          Gradient evaluations: 77
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.913466
#          Iterations: 4
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.701040
#          Iterations: 4
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.375357
#          Iterations: 2
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.736398
#          Iterations: 2
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.926643
#          Iterations: 2
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.682346
#          Iterations: 2
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.477065
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 66

# %% [markdown]
# ### Polynomial regression: expanding the basis functions
# The problem with our linear model was that it was too simple for the data
# and resulted in underfitting (high bias). In this problem, you will address this issue by adding more features. In particular, you will consider hypotheses of the form
# $$ h_\theta(x) = \theta_0 + \theta_1 x + \theta_2 x^2 + \ldots + \theta_p x^p $$
# This is still a linear model from the point of view of the parameter space. We have augmented the features with powers of $x$.
# Code in the cell below builds these features using sklearn's preprocessing module.
#
# We use a polynomial of degree 6.
# It turns out that if we run the training directly on the projected data,  it will
# not work well as the features would be badly scaled (e.g., an example with
# $x = 40$ will now have a feature $x^6 = 40^6 = 4.1 \times 10^{9}$). Therefore, you will
# need to use feature normalization.
# Before learning the parameter $\theta$ for the polynomial regression, the script in the cell below will
# first call the feature_normalize function you wrote earlier. It will normalize the features of the training set,
# storing the mu, sigma parameters separately. It will project the validation and test sets too, but normalize them using the same mu and sigma parameters.

# %%
from utils import feature_normalize
import sklearn
from sklearn.preprocessing import PolynomialFeatures

# Map X onto polynomial features and normalize
# We will consider a 6th order polynomial fit for the data

p = 6
poly = sklearn.preprocessing.PolynomialFeatures(degree=p,include_bias=False)
X_poly = poly.fit_transform(np.reshape(X,(len(X),1)))
X_poly, mu, sigma = utils.feature_normalize(X_poly)

# add a column of ones to X_poly

XX_poly = np.vstack([np.ones((X_poly.shape[0],)),X_poly.T]).T

# map Xtest and Xval into the same polynomial features

X_poly_test = poly.fit_transform(np.reshape(Xtest,(len(Xtest),1)))
X_poly_val = poly.fit_transform(np.reshape(Xval,(len(Xval),1)))

# normalize these two sets with the same mu and sigma

X_poly_test = (X_poly_test - mu) / sigma
X_poly_val = (X_poly_val - mu) / sigma

# add a column of ones to both X_poly_test and X_poly_val
XX_poly_test = np.vstack([np.ones((X_poly_test.shape[0],)),X_poly_test.T]).T
XX_poly_val = np.vstack([np.ones((X_poly_val.shape[0],)),X_poly_val.T]).T

# %% [markdown]
# ### Learning curves for polynomial regression
# The cell below trains a linear model on the transformed data. After learning $\theta$, you should see two plots
# generated for polynomial regression with $\lambda= 0$.

# %%
reg = 1
reglinear_reg2 = RegularizedLinearReg_SquaredLoss()
theta_opt1 = reglinear_reg1.train(XX_poly,y,reg=reg,num_iters=10000)
print 'Theta at lambda = 0 is ', theta_opt1


# plot data and training fit for the 6th order polynomial 

plot_utils.plot_fit(X,y,np.min(X),np.max(X),mu,sigma,theta_opt1,p,'Change in water level (x)','Water flowing out of dam (y)','Polynomial Regression fit with lambda = 0 and polynomial features of degree = ' + str(p))
plt.show()
#plt.savefig('fig9.pdf')

# plot learning curve for data (6th order polynomail basis function) 

error_train,error_val = utils.learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
#plt.savefig('fig10.pdf')
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.261483
#          Iterations: 11
#          Function evaluations: 97
#          Gradient evaluations: 85
# Theta at lambda = 0 is  [ 10.35716453   8.3993513    5.20905128   3.5897327    2.12310616
#    1.97431126   0.79714547]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.178609
#          Iterations: 3
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.107719
#          Iterations: 4
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.496097
#          Iterations: 2
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.474365
#          Iterations: 4
#          Function evaluations: 115
#          Gradient evaluations: 103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.024947
#          Iterations: 11
#          Function evaluations: 81
#          Gradient evaluations: 69
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.983262
#          Iterations: 10
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.691000
#          Iterations: 9
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.067409
#          Iterations: 10
#          Function evaluations: 92
#          Gradient evaluations: 80
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.275935
#          Iterations: 9
#          Function evaluations: 99
#          Gradient evaluations: 87
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.571825
#          Iterations: 10
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.261483
#          Iterations: 11
#          Function evaluations: 97
#          Gradient evaluations: 85

# %% [markdown]
# ### Adjusting the regularization parameter
# You will now explore how the regularization parameter
# affects the bias-variance of regularized polynomial regression. You should
# now modify the  lambda parameter in the cell above and try $\lambda = 1, 10, 100$. For
# each of these values, the script will generate a polynomial fit to the data
# and also a learning curve. Submit two plots for each value of lambda: the fit as well as the learning curve. Comment on the impact of the choice of lambda on the quality of the learned model in your lab writeup.

# %% [markdown]
# ### Calculating test error on the best model
# To get a better indication of a model's performance in the real
# world, it is important to evaluate the Äúfinal model on a test set that was
# not used in any part of training (that is, it was neither used to select the regularization parameter, nor to learn the model parameters).
# Calculate the error of the best model that you found with the previous analysis
# and report it.

# %%
# TODO: your code for computing test error on the best model (model with the best lambda)
reg=1
theta= np.array([ 10.35716453,8.3993513,5.20905128, 3.5897327,2.1231061,1.97431126, 0.79714547])
num_examples,dim = XX_poly_test.shape
J = 0
error = ytest - XX_poly_test.dot(theta.T)
J = error.T.dot(error)/2/num_examples
print J
# the code below is for plot
#error_train,error_test = utils.learning_curve(XX_poly,y,XX_poly_test,ytest,reg)
#plot_utils.plot_learning_curve(error_train,error_test,reg)

#plt.title('Learning curve for linear regression with lambda = '+str(reg))
#plt.xlabel('Number of training examples')
#plt.ylabel('Training/Test error')
#plt.legend(["Training error","Test error"])
#plt.show()
# Out:
# 4.34635603483

# %% [markdown]
# ### Selecting $\lambda$ using a validation set
# You will implement an automated method to select the $\lambda$ parameter. Concretely, you will use a validation set to evaluate how good each $\lambda$ value is. After selecting the best $\lambda$ value using the
# validation set, we can then evaluate the model on the test set to estimate
# how well the model will perform on actual unseen data.
# Complete the function validation_curve.m in utils.py. Specifically,
# you should should use the train method on an instance of the class Reg_Linear_Regressor to train the model using
# different values of $\lambda$ and to compute the training error and  validation error.
# You should try $\lambda$ in the following range: \{0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10\}.
#
# After you have completed the code, run the cell below to plot a validation curve of $\lambda$ versus the error. This plot  allows you select
# which $\lambda$ value to use. Due to randomness
# in the training and validation splits of the dataset, the cross validation error
# can sometimes be lower than the training error. Submit a pdf version of this plot in your report. Comment on the best choice of $\lambda$ for this problem.

# %%
# now implement the validation_curve function in utils.py
# this function helps in determining the best lambda using a
# a validation set
# The code will now run your function and plot the figure 

reg_vec, error_train, error_val = utils.validation_curve(XX_poly,y,XX_poly_val,yval)
plot_utils.plot_lambda_selection(reg_vec,error_train,error_val)
plt.show()
#plt.savefig('fig12.pdf')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.220253
#          Iterations: 44
#          Function evaluations: 46
#          Gradient evaluations: 46
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.260113
#          Iterations: 42
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.378321
#          Iterations: 38
#          Function evaluations: 121
#          Gradient evaluations: 109
# Optimization terminated successfully.
#          Current function value: 0.647644
#          Iterations: 39
#          Function evaluations: 41
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.377157
#          Iterations: 26
#          Function evaluations: 132
#          Gradient evaluations: 120
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.969903
#          Iterations: 12
#          Function evaluations: 120
#          Gradient evaluations: 108
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.261483
#          Iterations: 11
#          Function evaluations: 97
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.718539
#          Iterations: 5
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45.504393
#          Iterations: 5
#          Function evaluations: 107
#          Gradient evaluations: 95

# %% [markdown]
# ### Plotting learning curves with randomly selected examples
# In practice, especially for small training sets, when you plot learning curves
# to debug your algorithms, it is often helpful to average across multiple sets
# of randomly selected examples to determine the training error and
# validation error.
# Concretely, to determine the training error and cross validation error for
# $i$ examples, you should first randomly select $i$ examples from the training set
# and $i$ examples from the  validation set. You will then learn the model parameters using the randomly chosen training set and evaluate the parameters on the randomly chosen training set and validation set. The above
# steps should then be repeated multiple times (say 50) and the averaged error
# should be used to determine the training error and cross validation error for
# $i$ examples.
# Implement the above
# strategy for computing the learning curves. Complete the  function
# learning_curve_averaged} in  utils.py to generate compute and generate this plot. Then evaluate the cell below.

# %%
# now implement the averaged learning curve function in utils.py
# The script runs your function, plots the curves and saves it in fig11.pdf

reg = 1.0
error_train,error_val = utils.averaged_learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
#plt.savefig('fig11.pdf')
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.788554
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.523967
#          Iterations: 3
#          Function evaluations: 105
#          Gradient evaluations: 93
# Optimization terminated successfully.
#          Current function value: 36.627969
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.951051
#          Iterations: 3
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.291007
#          Iterations: 3
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37.031679
#          Iterations: 8
#          Function evaluations: 86
#          Gradient evaluations: 74
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.741881
#          Iterations: 5
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.219373
#          Iterations: 3
#          Function evaluations: 50
#          Gradient evaluations: 38
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.788554
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.268621
#          Iterations: 3
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.640893
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.081973
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34.579628
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.198508
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.320464
#          Iterations: 3
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.982812
#          Iterations: 4
#          Function evaluations: 99
#          Gradient evaluations: 87
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.982812
#          Iterations: 4
#          Function evaluations: 99
#          Gradient evaluations: 87
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.348646
#          Iterations: 3
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.215772
#          Iterations: 3
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.583803
#          Iterations: 2
#          Function evaluations: 95
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: 36.627969
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.574552
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.741881
#          Iterations: 5
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.048387
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.640893
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.387711
#          Iterations: 3
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.640893
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.951051
#          Iterations: 3
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.589824
#          Iterations: 4
#          Function evaluations: 84
#          Gradient evaluations: 72
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.361912
#          Iterations: 4
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.325197
#          Iterations: 5
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.589824
#          Iterations: 4
#          Function evaluations: 84
#          Gradient evaluations: 72
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.509758
#          Iterations: 3
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.057146
#          Iterations: 3
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.193822
#          Iterations: 3
#          Function evaluations: 115
#          Gradient evaluations: 103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.467972
#          Iterations: 3
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36.758984
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.193822
#          Iterations: 3
#          Function evaluations: 115
#          Gradient evaluations: 103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36.092181
#          Iterations: 8
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.373099
#          Iterations: 2
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.186862
#          Iterations: 4
#          Function evaluations: 95
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: 0.060297
#          Iterations: 4
#          Function evaluations: 6
#          Gradient evaluations: 6
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.057146
#          Iterations: 3
#          Function evaluations: 100
#          Gradient evaluations: 88
# Optimization terminated successfully.
#          Current function value: 36.627969
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.320464
#          Iterations: 3
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.268621
#          Iterations: 3
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.509758
#          Iterations: 3
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34.579628
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.051619
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.186862
#          Iterations: 4
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.146058
#          Iterations: 4
#          Function evaluations: 88
#          Gradient evaluations: 76
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.593477
#          Iterations: 3
#          Function evaluations: 114
#          Gradient evaluations: 102
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.858055
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.765586
#          Iterations: 4
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.805555
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.063470
#          Iterations: 6
#          Function evaluations: 46
#          Gradient evaluations: 35
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.233671
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.146571
#          Iterations: 4
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.188296
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.232592
#          Iterations: 3
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.839035
#          Iterations: 7
#          Function evaluations: 88
#          Gradient evaluations: 76
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.499745
#          Iterations: 7
#          Function evaluations: 86
#          Gradient evaluations: 74
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.925577
#          Iterations: 4
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.604725
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.310955
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.076834
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.394816
#          Iterations: 3
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.974761
#          Iterations: 4
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.742782
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.281098
#          Iterations: 2
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.858055
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.343423
#          Iterations: 4
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.853693
#          Iterations: 2
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.550844
#          Iterations: 3
#          Function evaluations: 115
#          Gradient evaluations: 103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.769418
#          Iterations: 4
#          Function evaluations: 97
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.586786
#          Iterations: 4
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.758577
#          Iterations: 5
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.858055
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.328668
#          Iterations: 4
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.555012
#          Iterations: 4
#          Function evaluations: 86
#          Gradient evaluations: 74
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.006547
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.477089
#          Iterations: 3
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.336125
#          Iterations: 8
#          Function evaluations: 82
#          Gradient evaluations: 70
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.063292
#          Iterations: 8
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.247703
#          Iterations: 4
#          Function evaluations: 82
#          Gradient evaluations: 70
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.160828
#          Iterations: 3
#          Function evaluations: 116
#          Gradient evaluations: 104
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.854594
#          Iterations: 6
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.533539
#          Iterations: 3
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.323217
#          Iterations: 4
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.013871
#          Iterations: 4
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.771984
#          Iterations: 2
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.100645
#          Iterations: 5
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.533073
#          Iterations: 4
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.533073
#          Iterations: 4
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.160571
#          Iterations: 3
#          Function evaluations: 116
#          Gradient evaluations: 104
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.493840
#          Iterations: 4
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.420990
#          Iterations: 5
#          Function evaluations: 53
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.189617
#          Iterations: 4
#          Function evaluations: 46
#          Gradient evaluations: 34
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.559869
#          Iterations: 5
#          Function evaluations: 92
#          Gradient evaluations: 80
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.687797
#          Iterations: 8
#          Function evaluations: 79
#          Gradient evaluations: 67
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.205085
#          Iterations: 4
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.865801
#          Iterations: 4
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.258571
#          Iterations: 4
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.024866
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.376873
#          Iterations: 5
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.321409
#          Iterations: 5
#          Function evaluations: 53
#          Gradient evaluations: 42
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.498482
#          Iterations: 4
#          Function evaluations: 117
#          Gradient evaluations: 105
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.185232
#          Iterations: 5
#          Function evaluations: 52
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.513762
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.144417
#          Iterations: 5
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.043839
#          Iterations: 7
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.649023
#          Iterations: 5
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.740130
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.163360
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.233681
#          Iterations: 5
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.528705
#          Iterations: 6
#          Function evaluations: 89
#          Gradient evaluations: 77
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.829661
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.763276
#          Iterations: 6
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.345125
#          Iterations: 4
#          Function evaluations: 118
#          Gradient evaluations: 106
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.814841
#          Iterations: 5
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.713724
#          Iterations: 4
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.486851
#          Iterations: 3
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.413508
#          Iterations: 7
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.871368
#          Iterations: 7
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.015678
#          Iterations: 5
#          Function evaluations: 90
#          Gradient evaluations: 78
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.649566
#          Iterations: 4
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.035264
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.319962
#          Iterations: 6
#          Function evaluations: 86
#          Gradient evaluations: 74
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.035611
#          Iterations: 6
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.376346
#          Iterations: 5
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.549021
#          Iterations: 8
#          Function evaluations: 97
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.168237
#          Iterations: 4
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.294952
#          Iterations: 4
#          Function evaluations: 44
#          Gradient evaluations: 33
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.927406
#          Iterations: 5
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.760583
#          Iterations: 5
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.411755
#          Iterations: 4
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.805939
#          Iterations: 5
#          Function evaluations: 97
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.054801
#          Iterations: 5
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.502216
#          Iterations: 5
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.149524
#          Iterations: 4
#          Function evaluations: 80
#          Gradient evaluations: 68
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.651820
#          Iterations: 4
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.411755
#          Iterations: 4
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.245263
#          Iterations: 3
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.349289
#          Iterations: 4
#          Function evaluations: 92
#          Gradient evaluations: 80
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.298197
#          Iterations: 7
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.993691
#          Iterations: 4
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.496097
#          Iterations: 2
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.970836
#          Iterations: 6
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.861315
#          Iterations: 5
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.817928
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.104607
#          Iterations: 7
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.560901
#          Iterations: 2
#          Function evaluations: 114
#          Gradient evaluations: 102
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.301944
#          Iterations: 4
#          Function evaluations: 55
#          Gradient evaluations: 44
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.382759
#          Iterations: 2
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.993331
#          Iterations: 6
#          Function evaluations: 87
#          Gradient evaluations: 75
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.969567
#          Iterations: 11
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.215001
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.988699
#          Iterations: 6
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.893313
#          Iterations: 4
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.237509
#          Iterations: 5
#          Function evaluations: 47
#          Gradient evaluations: 36
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.502182
#          Iterations: 4
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.630031
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.518918
#          Iterations: 7
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.633451
#          Iterations: 5
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.737092
#          Iterations: 5
#          Function evaluations: 99
#          Gradient evaluations: 87
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.131222
#          Iterations: 6
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.215239
#          Iterations: 7
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.565531
#          Iterations: 4
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.356471
#          Iterations: 6
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.130998
#          Iterations: 7
#          Function evaluations: 99
#          Gradient evaluations: 87
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.289142
#          Iterations: 5
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.932749
#          Iterations: 5
#          Function evaluations: 90
#          Gradient evaluations: 78
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.070079
#          Iterations: 5
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.775866
#          Iterations: 6
#          Function evaluations: 91
#          Gradient evaluations: 79
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.093348
#          Iterations: 6
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.654430
#          Iterations: 5
#          Function evaluations: 52
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.620535
#          Iterations: 5
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.825966
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.009467
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.438560
#          Iterations: 7
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.080478
#          Iterations: 5
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.272572
#          Iterations: 5
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.742398
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.329291
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.505429
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.229833
#          Iterations: 5
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.755113
#          Iterations: 2
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.350846
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.573224
#          Iterations: 4
#          Function evaluations: 115
#          Gradient evaluations: 103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.510111
#          Iterations: 4
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.367040
#          Iterations: 5
#          Function evaluations: 91
#          Gradient evaluations: 79
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.906652
#          Iterations: 5
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.393968
#          Iterations: 5
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.456917
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.225664
#          Iterations: 2
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.964011
#          Iterations: 3
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.532575
#          Iterations: 6
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.663403
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.606961
#          Iterations: 5
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.076137
#          Iterations: 8
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.667534
#          Iterations: 5
#          Function evaluations: 113
#          Gradient evaluations: 101
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.630484
#          Iterations: 4
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.276094
#          Iterations: 6
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.326678
#          Iterations: 5
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.188348
#          Iterations: 7
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.773031
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.288374
#          Iterations: 8
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.835834
#          Iterations: 6
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.415432
#          Iterations: 8
#          Function evaluations: 114
#          Gradient evaluations: 102
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.527617
#          Iterations: 7
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.144315
#          Iterations: 15
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.477195
#          Iterations: 9
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.956123
#          Iterations: 5
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.719148
#          Iterations: 5
#          Function evaluations: 90
#          Gradient evaluations: 78
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.144315
#          Iterations: 15
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.906845
#          Iterations: 12
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.570568
#          Iterations: 7
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.981355
#          Iterations: 8
#          Function evaluations: 88
#          Gradient evaluations: 76
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.456167
#          Iterations: 6
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.459851
#          Iterations: 6
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.026703
#          Iterations: 5
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.370947
#          Iterations: 2
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.106408
#          Iterations: 10
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.411593
#          Iterations: 5
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.554949
#          Iterations: 5
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.440794
#          Iterations: 10
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 16.399685
#          Iterations: 5
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.040642
#          Iterations: 17
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.482043
#          Iterations: 5
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.764083
#          Iterations: 5
#          Function evaluations: 78
#          Gradient evaluations: 66
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.256695
#          Iterations: 4
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.237708
#          Iterations: 7
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.440662
#          Iterations: 5
#          Function evaluations: 97
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.598034
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# ...
#          Current function value: 6.575393
#          Iterations: 9
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.349375
#          Iterations: 9
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.088255
#          Iterations: 7
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.839714
#          Iterations: 12
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.446810
#          Iterations: 4
#          Function evaluations: 58
#          Gradient evaluations: 47
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.038278
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.264428
#          Iterations: 8
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.777821
#          Iterations: 6
#          Function evaluations: 57
#          Gradient evaluations: 47
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.582557
#          Iterations: 6
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.347145
#          Iterations: 10
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.889814
#          Iterations: 6
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.003337
#          Iterations: 9
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.620793
#          Iterations: 26
#          Function evaluations: 129
#          Gradient evaluations: 117
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.693968
#          Iterations: 13
#          Function evaluations: 64
#          Gradient evaluations: 52
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.733473
#          Iterations: 5
#          Function evaluations: 90
#          Gradient evaluations: 78
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.448604
#          Iterations: 4
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.931962
#          Iterations: 8
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.778274
#          Iterations: 10
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.551560
#          Iterations: 10
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.696910
#          Iterations: 9
#          Function evaluations: 88
#          Gradient evaluations: 76
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.421603
#          Iterations: 16
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.402989
#          Iterations: 10
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.421633
#          Iterations: 9
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.701546
#          Iterations: 8
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.799106
#          Iterations: 8
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.583356
#          Iterations: 5
#          Function evaluations: 95
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.178714
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.480845
#          Iterations: 9
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.157634
#          Iterations: 11
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.017411
#          Iterations: 12
#          Function evaluations: 116
#          Gradient evaluations: 104
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.509918
#          Iterations: 11
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.491887
#          Iterations: 9
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.532664
#          Iterations: 5
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.180783
#          Iterations: 7
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.235014
#          Iterations: 11
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.040075
#          Iterations: 10
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.356394
#          Iterations: 10
#          Function evaluations: 57
#          Gradient evaluations: 46
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.990414
#          Iterations: 12
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.581421
#          Iterations: 7
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.601646
#          Iterations: 8
#          Function evaluations: 99
#          Gradient evaluations: 87
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.681908
#          Iterations: 8
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.701146
#          Iterations: 8
#          Function evaluations: 84
#          Gradient evaluations: 72
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.313699
#          Iterations: 9
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.438984
#          Iterations: 15
#          Function evaluations: 83
#          Gradient evaluations: 71
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.288548
#          Iterations: 17
#          Function evaluations: 118
#          Gradient evaluations: 106
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.394323
#          Iterations: 6
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.346144
#          Iterations: 8
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.856899
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.957197
#          Iterations: 8
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.715127
#          Iterations: 9
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.554574
#          Iterations: 12
#          Function evaluations: 68
#          Gradient evaluations: 58
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.582136
#          Iterations: 9
#          Function evaluations: 64
#          Gradient evaluations: 53
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.532472
#          Iterations: 12
#          Function evaluations: 97
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.670165
#          Iterations: 14
#          Function evaluations: 89
#          Gradient evaluations: 77
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.623171
#          Iterations: 7
#          Function evaluations: 109
#          Gradient evaluations: 97
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.992141
#          Iterations: 13
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.553256
#          Iterations: 11
#          Function evaluations: 88
#          Gradient evaluations: 76
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.501137
#          Iterations: 8
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.045458
#          Iterations: 12
#          Function evaluations: 100
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.832065
#          Iterations: 9
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.768772
#          Iterations: 11
#          Function evaluations: 107
#          Gradient evaluations: 95
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.068155
#          Iterations: 7
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.260911
#          Iterations: 4
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.928642
#          Iterations: 9
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.412262
#          Iterations: 7
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.493736
#          Iterations: 9
#          Function evaluations: 111
#          Gradient evaluations: 99
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.149425
#          Iterations: 14
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.414836
#          Iterations: 11
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.039378
#          Iterations: 11
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.022088
#          Iterations: 13
#          Function evaluations: 112
#          Gradient evaluations: 100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.791841
#          Iterations: 7
#          Function evaluations: 59
#          Gradient evaluations: 48
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.758320
#          Iterations: 10
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.321173
#          Iterations: 11
#          Function evaluations: 70
#          Gradient evaluations: 60
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.314707
#          Iterations: 7
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.248768
#          Iterations: 10
#          Function evaluations: 94
#          Gradient evaluations: 82
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.432306
#          Iterations: 12
#          Function evaluations: 102
#          Gradient evaluations: 90
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.977158
#          Iterations: 13
#          Function evaluations: 89
#          Gradient evaluations: 77
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.091717
#          Iterations: 13
#          Function evaluations: 99
#          Gradient evaluations: 87

# %% [markdown]
# ### Extra Credit: Building regularized models for the Boston housing data set
# Perform a bias variance analysis of the Boston housing data set with the thirteen predictors, following the steps on the simple data set above. Use sklearn's  built-in functions to split the data into training, validation and test sets. What is the lowest achievable error on the test set with $\lambda = 0$? Select the best value for $\lambda$ and report the test set error with the best $\lambda$. Use the technique of adding features to extend each column of the Boston data set with powers of the values in the column. Repeat the bias-variance analysis with quadratic and cubic features. What is the test set error with quadratic features with the best $\lambda$ chosen with the validation set? What is the test set error with cubic features with the best $\lambda$ chosen with the validation set? Put your analysis code in a separate Python script or notebook called bostonexpt.py or bostonexpt.ipynb. Present your results analytically with plots to support your findings. Discuss the impact of regularization for building good models for the Boston housing data set.

# %%
### TODO: your Boston code here or in a separate notebook.
